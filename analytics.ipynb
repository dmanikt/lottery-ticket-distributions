# %% [markdown]
# Fixed:
# Batch size: 256
# Optimizer: Adam w/ lr=1e-4
# Criterion: Cross Entropy (maybe add L2 weight decay)
# Num Epochs: 300
# Pruning s, j, n = .25, 5, 10 (stages at n=0 (1.0000), n=2 (.5625), n=5 (.2373), n=8 (.1001), n=10 (.0056))
#
# page 14 of https://arxiv.org/pdf/1803.03635.pdf
#
# for each dataset: (4)
#     for each model: (4)
#         for each trial: (1)
#             run w/ full topography, theta_0 initialization
#             run iterative pruning on w/ full topography, theta_0 initialization
#              for each pruning stage: (4)
#                 refresh run w/ full topography, D_new initialization
#                 refresh run w/ pruned topography, theta_0 initialization
#                 refresh run w/ pruned topography, D_0 initialization
#                 refresh run w/ pruned topography, D_new initialization
#                 ##refresh run w/ random topography, D_new initialization
#
# RECORDING:
#     0, 75, 150, 225, 300
#     the distribution of weights before and after training, as well as every 75 epochs
#     train and test loss
#     test accuracy

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
files = ['outputs/mnist/fc1/trial_1/0.txt',
         'outputs/mnist/fc1/trial_1/1.txt',
         'outputs/mnist/fc1/trial_1/3.txt',
         'outputs/mnist/fc1/trial_1/5.txt']

# %%
for f in files:
    b = np.load(f)
    plt.hist(b)
    plt.title('{}: {}'.format(f,b.size))
    plt.show()

# %%
x = y = np.zeros(5)
x[0] = 5
y
# Out:
# array([5., 0., 0., 0., 0.])
